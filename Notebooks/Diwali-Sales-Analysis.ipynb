# %% [markdown]
# # Project Title: Diwali Sales Analytics

# %% [markdown]
# ## Project Summary
#
# The **Diwali Sales Analytics** project is designed to help businesses understand customer behavior, product performance, and regional sales patterns during the festive season. Using Python and libraries such as **pandas, numpy, matplotlib, and seaborn**, this project performs detailed data analysis on Diwali sales data to generate actionable insights for marketing, inventory optimization, and sales planning.
#
# ### The analysis focuses on:
#
# ### 1. Customer Demographics & Behavior
# - Understanding purchasing patterns based on **age, gender, marital status, and occupation**.
# - Identifying **repeat and high-value customers** to improve targeting strategies.
#
# ### 2. Product & Revenue Analysis
# - Determining **top-selling products** and **high-performing product categories**.
# - Analyzing **revenue trends**, daily sales patterns, and the **impact of discounts** on sales.
#
# ### 3. Regional Sales Patterns
# - Evaluating **state-wise** and **zone-wise** sales performance.
# - Identifying **regional preferences** for products and categories to optimize stock and marketing.
#
# ### 4. Advanced Insights
# - Segmenting customers for **targeted marketing campaigns**.
# - Visualizing product performance using **heatmaps and trend charts**.
# - Forecasting **future Diwali sales** using historical trends.

# %% [markdown]
# ## Problem Statement
#
# During the festive season, businesses witness a significant surge in customer purchases. Understanding **customer behavior**, **product preferences**, and **regional sales patterns** is crucial to maximize revenue and plan effective, targeted marketing strategies.
#
# This project analyzes **Diwali sales data** to uncover:
#
# - Customer demographics and purchasing behavior based on **age, gender, marital status, and occupation**.
# - **High-performing product categories** and overall **revenue trends**.
# - **Regional sales patterns** across different **states and zones**.
#
# The goal of this analysis is to help businesses make **data-driven decisions** for marketing, inventory planning, and sales optimization during the Diwali festive season.

# %% [markdown]
# ## Objective
#
# The objective of this project is to provide **actionable insights** that support:
#
# - Effective **marketing strategies** through customer segmentation and behavior analysis.
# - **Inventory optimization** by identifying high-demand products and categories.
# - Improved **sales planning** by understanding revenue trends and regional sales performance during the Diwali festive season.

# %% [markdown]
# ## Outcome
#
# This project provides businesses with valuable insights to:
#
# - **Increase revenue** by targeting the right customer segments.
# - **Optimize inventory management** by stocking high-demand products.
# - **Plan region-specific marketing campaigns** based on customer and sales trends.
#
# ## Technologies Used
#
# - **Python**
# - **Jupyter Notebook**
# - **pandas**
# - **numpy**
# - **matplotlib**
# - **seaborn**

# %% [markdown]
# # 🎉 Let’s Dive Into Diwali Sales Analytics!
# ### Uncovering Customer Behavior, Product Trends, and Regional Insights During the Festive Season

# %% [markdown]
# ## 1. Know Your Data
#
# **What it is:**
# Examining the dataset to understand its structure, size, column types, and basic statistics.
#
# **Why we use it:**
# To get an overall idea of the data, identify potential issues like missing values or incorrect data types, and plan the cleaning and analysis steps effectively.

# %% [markdown]
# #### Import Libraries
#
# **What it is:**
# Loading Python libraries like **pandas, numpy, matplotlib, seaborn** that provide tools for data manipulation, analysis, and visualization.
#
# **Why we use it:**
# These libraries make it easy to **read, clean, explore, and visualize data efficiently**, which is essential for any data analysis project.

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Optional: To display plots inline in Jupyter Notebook
# %matplotlib inline

# Set seaborn style
sns.set(style="whitegrid")

# %% [markdown]
# #### Load Dataset
#
# **What it is:**
# Reading the data file (CSV/Excel) into a Python environment as a DataFrame using **pandas**.
#
# **Why we use it:**
# To bring the dataset into the workspace so we can **analyze, manipulate, and visualize** it programmatically.

# %%
# Read the CSV file
df = pd.read_csv(r"C:\Users\Prafull Wahatule\Desktop\Diwali Sales Analytics - Pyhton\Data\Diwali Sales Data.csv")

# %% [markdown]
# #### Take a Look at Data
#
# **What it is:**
# Using `df.head()` to display the first few rows of the dataset.
#
# **Why we use it:**
# To get a **quick preview** of the data, understand column names, and check if the data has been loaded correctly.

# %%
# Display the first few rows
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# #### Dataset Rows & Columns Count
#
# **What it is:**
# Checking the number of rows and columns in the dataset using `df.shape`.
#
# **Why we use it:**
# To understand the **size and dimensions** of the dataset, which helps in planning the analysis and knowing how much data we are dealing with.

# %%
# Dataset Rows & Columns count
df.index
# Out:
# RangeIndex(start=0, stop=11251, step=1)

# %%
# Getting Information of total Column & Rows
df.shape
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# #### Getting Dataset Information
#
# **What it is:**
# Using `df.info()` to get details about column names, data types, non-null counts, and memory usage.
#
# **Why we use it:**
# To quickly **identify data types, missing values, and overall structure** of the dataset, which helps in planning data cleaning and analysis steps.

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Duplicate Values
#
# **What it is:**
# Checking for duplicate rows in the dataset using `df.duplicated().value_counts()`.
#
# **Why we use it:**
# To **identify and remove duplicate records**, ensuring that analysis and insights are accurate and not skewed by repeated data.

# %%
# Dataset Duplicate Value Count
duplicate_values = df.duplicated().value_counts()  
duplicate_values
# Out:
# False    11243
# True         8
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Data Cleaning & Data Wrangling
#
# **What it is:**
# The process of **handling missing values, removing duplicates, correcting data types, and dropping unnecessary columns** to make the dataset consistent and analysis-ready.
#
# **Why we use it:**
# Clean data ensures **accurate, reliable, and meaningful analysis**. Without cleaning, insights may be incorrect or misleading.

# %% [markdown]
# #### Drop Columns
#
# **What it is:**
# Removing unnecessary or irrelevant columns from the dataset using `df.drop()`.
#
# **Why we use it:**
# To **simplify the dataset**, reduce clutter, and focus only on the columns that are important for analysis.

# %%
# Drop columns with all null values
df.drop(columns=['Status', 'unnamed1'], inplace=True)

# %%
# Check Current Columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# #### Fill Missing Amount Values
#
# **What it is:**
# Replacing missing values in the `Amount` column using methods like `fillna()` with median or zero.
#
# **Why we use it:**
# To ensure that **sales calculations and analysis are accurate**, since missing values can skew totals, averages, and other insights.

# %%
# Fill missing Amount values with 0 or median
df['Amount'] = df['Amount'].fillna(df['Amount'].median())

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# #### Rename Columns to Remove Spaces
#
# **What it is:**
# Renaming columns (e.g., `'Age Group'` → `'Age_Group'`) using `df.rename()` to remove spaces.
#
# **Why we use it:**
# To make column names **easier to reference in code**, avoid syntax errors, and improve readability during analysis.

# %%
# Rename columns to remove spaces for easier coding
df.rename(columns={'Age Group':'Age_Group'}, inplace=True)

# %%
# Check Current Columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# #### Check & Drop Duplicate Records
#
# **What it is:**
# Identifying duplicate rows using `df.duplicated()` and removing them with `df.drop_duplicates()`.
#
# **Why we use it:**
# To ensure that each transaction is **unique**, preventing inflated counts or skewed analysis results caused by repeated data.

# %%
#Check Duplicate Records
df.duplicated().value_counts()
# Out:
# False    11243
# True         8
# Name: count, dtype: int64

# %%
# Drop Duplicate Records
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Verify Data After Cleaning
#
# **What it is:**
# Checking the dataset after cleaning using `df.info()`, `df.shape`, and `df.head()` to ensure all issues are resolved.
#
# **Why we use it:**
# To **confirm that missing values are handled, duplicates are removed, and columns are correctly formatted**, making the dataset fully ready for analysis.

# %%
# Verify Data After Cleaning

df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age_Group         11243 non-null  object
#  5   Age               11243 non-null  int64
#  6   Marital_Status    11243 non-null  int64
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11243 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.2+ MB
# (11243, 13)

# %% [markdown]
# ### Final Dataset Preview
#
# **What it is:**
# Displaying the first few rows of the cleaned dataset using `df.head()`.
#
# **Why we use it:**
# To **visually inspect** the cleaned data, verify column names, data types, and sample values before starting detailed analysis.

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age_Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %% [markdown]
# ### After Data Cleaning – Dataset Overview
#
# After exploring and cleaning the Diwali Sales dataset, we gained the following insights about its structure and quality:
#
# - The dataset contains **11,243 unique records** and **13 relevant features** after cleaning.
# - There are **no missing values** in any column, making the dataset reliable for analysis.
# - The data includes both:
#   - **Numerical variables:** Age, Orders, Amount
#   - **Categorical variables:** Gender, Age Group, State, Zone, Occupation, Product Category
# - Each row represents a **customer purchase transaction during the Diwali festive season**.
# - Customer demographic information such as **age, gender, marital status, and occupation** is available.
# - Sales-related details include **number of orders** and **total purchase amount**.
# - Regional information like **state and zone** helps analyze geographical sales patterns.
# - Overall, the dataset is **clean, consistent, and analysis-ready**, making it suitable for **exploratory data analysis and business insight generation**.

# %% [markdown]
# ## 3. Understanding Your Variables
#
# **What it is:**
# Examining each column to understand the type of data it holds (numerical or categorical) and what it represents in the context of the project.
#
# **Why we use it:**
# To ensure we **know what each variable means**, decide which type of analysis or visualization is appropriate, and prepare for meaningful insights.

# %%
# Dataset Columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age_Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#              User_ID Cust_name Product_ID Gender Age_Group           Age  \
# count   1.124300e+04     11243      11243  11243     11243  11243.000000
# unique           NaN      1250       2351      2         7           NaN
# top              NaN  Vishakha  P00265242      F     26-35           NaN
# freq             NaN        42         53   7838      4538           NaN
# mean    1.003005e+06       NaN        NaN    NaN       NaN     35.422841
# std     1.716141e+03       NaN        NaN    NaN       NaN     12.756369
# min     1.000001e+06       NaN        NaN    NaN       NaN     12.000000
# 25%     1.001494e+06       NaN        NaN    NaN       NaN     27.000000
# 50%     1.003065e+06       NaN        NaN    NaN       NaN     33.000000
# 75%     1.004430e+06       NaN        NaN    NaN       NaN     43.000000
# max     1.006040e+06       NaN        NaN    NaN       NaN     92.000000
#
#         Marital_Status          State     Zone Occupation    Product_Category  \
# ...

# %% [markdown]
# ### Column-wise Understanding
#
# - **User_ID:** Unique identifier for each customer.
#   *Why:* Helps track individual transactions and customer-level analysis.
#
# - **Cust_name:** Name of the customer.
#   *Why:* Mainly for reference; not used in numerical analysis.
#
# - **Product_ID:** Unique identifier for each product.
#   *Why:* Useful for product-level analysis and revenue tracking.
#
# - **Gender:** Customer's gender (M/F).
#   *Why:* Enables demographic analysis and gender-based purchasing trends.
#
# - **Age_Group:** Customer's age range (e.g., 26-35).
#   *Why:* Helps understand purchasing behavior by age segment.
#
# - **Age:** Exact age of the customer.
#   *Why:* Allows more precise demographic analysis and age-based segmentation.
#
# - **Marital_Status:** Customer's marital status (0 = Single, 1 = Married).
#   *Why:* Useful to analyze buying patterns based on marital status.
#
# - **State:** State where the customer resides.
#   *Why:* Supports regional sales analysis and location-based insights.
#
# - **Zone:** Geographical zone (e.g., Northern, Southern).
#   *Why:* Helps group states into zones for broader regional analysis.
#
# - **Occupation:** Customer's occupation (e.g., Healthcare, Govt).
#   *Why:* Allows analysis of purchasing trends by profession.
#
# - **Product_Category:** Category of the purchased product (e.g., Electronics, Auto).
#   *Why:* Identifies high-performing product categories and sales trends.
#
# - **Orders:** Number of items ordered per transaction.
#   *Why:* Helps calculate total quantity sold and understand order behavior.
#
# - **Amount:** Total purchase amount for the transaction.
#   *Why:* Key metric for revenue analysis and financial insights.

# %% [markdown]
# ## 4. Data Visualization
#
# **What it is:**
# The process of creating **graphs, charts, and plots** to visually represent data using libraries like **matplotlib** and **seaborn**.
#
# **Why we use it:**
# To **identify patterns, trends, and relationships** in the data quickly, making insights easier to understand and communicate to stakeholders.

# %% [markdown]
# ### 1. Customer Demographics & Behavior

# %% [markdown]
# 1. **Age-wise Sales Analysis**
#    - **Scenario:** You want to know which age group is buying the most during Diwali.
#    - **Question:** Which age group contributes the highest revenue, and how does purchase frequency vary by age group?

# %%
# Count of orders per age group
age_group_counts = df["Age_Group"].value_counts()
#print(age_group_counts)

# Total revenue per age group
age_group_revenue = df.groupby("Age_Group")["Amount"].sum().sort_values(ascending=False)
#print(age_group_revenue)

# Visualization
plt.figure(figsize=(8,5))
# sns.barplot(x=age_group_revenue.index, y=age_group_revenue.values, palette="viridis")
sns.barplot(x=age_group_revenue.index, y=age_group_revenue.values, color="skyblue")
plt.title("Revenue by Age Group during Diwali")
plt.ylabel("Total Revenue")
plt.xlabel("Age Group")
plt.show()

# %% [markdown]
# 2. **Gender-based Purchasing Patterns**
#    - **Scenario:** The marketing team wants to target customers by gender.
#    - **Question:** What is the total revenue from male vs female customers? Which gender prefers which product category?

# %%
# Total revenue per age group
gender_wise_revenue = df.groupby("Gender")["Amount"].sum()
# gender_wise_revenue

# Visualization
plt.figure(figsize=(8,5))
plt.pie(
    gender_wise_revenue.values,
    labels=gender_wise_revenue.index,
    autopct='%1.1f%%',
    startangle=140
)
plt.title("Revenue by Gender during Diwali")
plt.show()

# %% [markdown]
# 3. **Marital Status Impact**
#    - **Scenario:** Sales team wants to know if marital status affects buying patterns.
#    - **Question:** Do married customers spend more than unmarried ones? Which categories are preferred by married vs unmarried customers?

# %%
# Total spending by marital status
marital_spend = df.groupby("Marital_Status")["Amount"].sum()
# marital_spend

# Visualization
plt.figure(figsize=(6,4))
sns.barplot(
    x=marital_spend.index,
    y=marital_spend.values
)
plt.title("Total Spending by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Total Amount")
plt.show()

# %% [markdown]
# 4. **Occupation vs Purchase Behavior**
#    - **Scenario:** The business wants to run targeted campaigns for different occupations.
#    - **Question:** Which occupations contribute most to revenue? Which product categories are popular among students, professionals, or homemakers?

# %%
# Total spending by Occupation
Occupation_Spend = (
    df.groupby("Occupation")["Amount"]
    .sum()
    .sort_values(ascending=False)
)

# Visualization
plt.figure(figsize=(15,5))
sns.barplot(
    x=Occupation_Spend.index,
    y=Occupation_Spend.values
)
plt.title("Total Revenue by Occupation")
plt.xlabel("Occupation")
plt.ylabel("Total Amount")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 5. **Customer Loyalty Analysis**
#    - **Scenario:** Identify repeat customers to offer them loyalty discounts.
#    - **Question:** Which customers purchased more than once during Diwali? How much revenue do repeat customers generate compared to one-time buyers?

# %%
# Aggregate at customer level
customer_orders = (
    df.groupby("User_ID")
    .agg(
        total_orders=("Orders", "sum"),
        total_spend=("Amount", "sum")
    )
    .reset_index()
)

# Classify customers
customer_orders["Customer_Type"] = customer_orders["total_orders"].apply(
    lambda x: "Repeat Customer" if x > 1 else "One-Time Buyer"
)

# Revenue comparison
revenue_by_type = (
    customer_orders.groupby("Customer_Type")["total_spend"]
    .sum()
    .reset_index()
    .sort_values("total_spend", ascending=False)
)

# Visualization
plt.figure(figsize=(6,4))
ax = sns.barplot(
    data=revenue_by_type,
    x="Customer_Type",
    y="total_spend"
)

for p in ax.patches:
    ax.annotate(
        f'{p.get_height():,.0f}',
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='bottom'
    )

plt.title("Revenue: Repeat vs One-Time Customers")
plt.xlabel("Customer Type")
plt.ylabel("Total Revenue")
plt.show()

# Customer count
customer_orders["Customer_Type"].value_counts()
# Out:
# Customer_Type
# Repeat Customer    3401
# One-Time Buyer      354
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Product & Revenue Analysis

# %% [markdown]
# 6. **Top Selling Products**
#    - **Scenario:** Inventory team needs to know which products to stock more.
#    - **Question:** What are the top 10 products by sales volume and revenue?

# %%
# Top 10 Products by Sales Volume

top_products_volume = (
    df.groupby("Product_ID")["Orders"]
    .sum()
    .reset_index()
    .sort_values("Orders", ascending=False)
    .head(10)
)

top_products_volume


# Visualization: Sales Volume
plt.figure(figsize=(10,5))
sns.barplot(
    data=top_products_volume,
    x="Product_ID",
    y="Orders"
)
plt.title("Top 10 Products by Sales Volume")
plt.xlabel("Product ID")
plt.ylabel("Total Orders")
plt.xticks(rotation=45)
plt.show()


# Top 10 Products by Revenue

top_products_revenue = (
    df.groupby("Product_ID")["Amount"]
    .sum()
    .reset_index()
    .sort_values("Amount", ascending=False)
    .head(10)
)

top_products_revenue


# Visualization: Revenue
plt.figure(figsize=(10,5))
sns.barplot(
    data=top_products_revenue,
    x="Product_ID",
    y="Amount"
)
plt.title("Top 10 Products by Revenue")
plt.xlabel("Product ID")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 7. **Category-wise Revenue Analysis**
#    - **Scenario:** Marketing wants to push high-revenue categories.
#    - **Question:** Which product categories generate the highest revenue? Which categories have the highest growth compared to last year?

# %%
# Category-wise revenue
category_by_revenue = (
    df.groupby("Product_Category")["Amount"]
    .sum()
    .reset_index()
    .sort_values("Amount", ascending=False)
)

category_by_revenue

# Visualization: Sales Volume
plt.figure(figsize=(10,5))
sns.barplot(
    data=category_by_revenue,
    x="Product_Category",
    y="Amount"
)
plt.title("Revenue by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 8. **Price vs Quantity Analysis**
#    - **Scenario:** To plan discounts, you need to see the relationship between product price and quantity sold.
#    - **Question:** Are high-priced items selling less than low-priced items? What is the correlation between price and quantity sold?

# %%
# Aggregate at product level
product_sales = (
    df.groupby("Product_ID")
    .agg(
        total_quantity=("Orders", "sum"),
        total_revenue=("Amount", "sum")
    )
    .reset_index()
)

# Derive unit price
product_sales["Unit_Price"] = (
    product_sales["total_revenue"] / product_sales["total_quantity"]
)

product_sales.head()

# Visualization
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=product_sales,
    x="Unit_Price",
    y="total_quantity"
)

plt.title("Price vs Quantity Sold")
plt.xlabel("Unit Price")
plt.ylabel("Total Quantity Sold")
plt.show()


correlation = product_sales["Unit_Price"].corr(
    product_sales["total_quantity"]
)

correlation
# Out:
# np.float64(-0.1768252047605547)

# %% [markdown]
# 9. **Discount Impact**
#     - **Scenario:** Marketing team wants to measure effectiveness of discounts.
#     - **Question:** Do products with discounts sell significantly more than products without discounts? How does discount percentage affect revenue?

# %%
# Aggregate at product level
product_sales = (
    df.groupby("Product_ID")
    .agg(
        total_quantity=("Orders", "sum"),
        total_revenue=("Amount", "sum")
    )
    .reset_index()
)

# Derive unit price
product_sales["Unit_Price"] = (
    product_sales["total_revenue"] / product_sales["total_quantity"]
)

# Split products into Low-price vs High-price (proxy for discount)
median_price = product_sales["Unit_Price"].median()

product_sales["Price_Type"] = product_sales["Unit_Price"].apply(
    lambda x: "Lower Priced (Discounted Proxy)" if x <= median_price else "Higher Priced"
)

product_sales.head()

quantity_comparison = (
    product_sales.groupby("Price_Type")["total_quantity"]
    .mean()
    .reset_index()
)

quantity_comparison

# Visualization
plt.figure(figsize=(6,4))
sns.barplot(
    data=quantity_comparison,
    x="Price_Type",
    y="total_quantity"
)
plt.title("Quantity Sold: Lower vs Higher Priced Products (Proxy)")
plt.xlabel("Product Type")
plt.ylabel("Average Quantity Sold")
plt.show()

# %% [markdown]
# ### 3. Regional Sales Analysis

# %% [markdown]
# 11. **State-wise Revenue Analysis**
#     - **Scenario:** Regional managers need insights for stock allocation.
#     - **Question:** Which states generate the most revenue? Which product categories are preferred in different states?

# %%
# State-wise Revenue Analysis

# Calculate total revenue by state
statewise_revenue = (
    df.groupby("State")["Amount"]
    .sum()
    .reset_index()
    .sort_values("Amount", ascending=False)
)

statewise_revenue

# Visualization: Revenue by State
plt.figure(figsize=(10,5))
sns.barplot(
    data=statewise_revenue,
    x="State",
    y="Amount"
)
plt.title("Revenue by State")
plt.xlabel("State")
plt.ylabel("Total Revenue")
plt.xticks(rotation=45)
plt.show()


# Product Category Preference by State

# Revenue by State and Product Category
state_category_revenue = (
    df.groupby(["State", "Product_Category"])["Amount"]
    .sum()
    .reset_index()
)

state_category_revenue.head()


# Identify top product category in each state
top_category_per_state = (
    state_category_revenue
    .sort_values(["State", "Amount"], ascending=[True, False])
    .groupby("State")
    .head(1)
    .reset_index(drop=True)
)

top_category_per_state


# Visualization
plt.figure(figsize=(10,5))
sns.barplot(
    data=top_category_per_state,
    x="State",
    y="Amount",
    hue="Product_Category"
)
plt.title("Top Product Category by Revenue in Each State")
plt.xlabel("State")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 12. **Zone-wise Sales Distribution**
#     - **Scenario:** Management wants to focus marketing on high-performing zones.
#     - **Question:** How is revenue distributed across North, South, East, and West zones?

# %%
# Zone-wise revenue
zonewise_revenue = (
    df.groupby("Zone")["Amount"]
    .sum()
    .reset_index()
    .sort_values("Amount", ascending=False)
)

zonewise_revenue

# bar chart
plt.figure(figsize=(8,5))
sns.barplot(
    data=zonewise_revenue,
    x="Zone",
    y="Amount"
)
plt.title("Revenue by Zone")
plt.xlabel("Zone")
plt.ylabel("Total Revenue")
plt.show()

# %% [markdown]
# 13. **Top Cities by Revenue**
#     - **Scenario:** Logistics team wants to optimize delivery.
#     - **Question:** Which cities generate the highest sales during Diwali?

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age_Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %% [markdown]
# 14. **Regional Product Preference**
#     - **Scenario:** Product managers want to tailor inventory regionally.
#     - **Question:** Which product categories are most popular in each zone or state?

# %% [markdown]
# ### 4. Advanced Analytical Scenarios

# %% [markdown]
# 15. **Customer Segmentation for Marketing**
#     - **Scenario:** Targeted marketing campaigns for high-value customers.
#     - **Question:** Segment customers into high, medium, and low spenders. Which segment contributes most to revenue?

# %% [markdown]
# 16. **Revenue Contribution by Customer Demographics**
#     - **Scenario:** Understanding which demographic groups are most profitable.
#     - **Question:** Which combination of age, gender, and occupation contributes the most revenue?

# %% [markdown]
# 17. **Cross-Category Buying Patterns**
#     - **Scenario:** Identify upselling opportunities.
#     - **Question:** Which customers buy multiple categories? Are there patterns in cross-category purchases?

# %% [markdown]
# 18. **Revenue Forecasting**
#     - **Scenario:** Predicting future Diwali sales based on historical trends.
#     - **Question:** Can we predict total revenue for the next Diwali season using past sales trends?

# %% [markdown]
# 19. **Product Performance Heatmap**
#     - **Scenario:** Visualizing performance for quick insights.
#     - **Question:** Create a heatmap showing revenue of product categories across different states.

# %% [markdown]
# 20. **High-Value Customer Targeting**
#     - **Scenario:** Increase loyalty among top customers.
#     - **Question:** Who are the top 5% of customers contributing to revenue, and what are their buying habits?
